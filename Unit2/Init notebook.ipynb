# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Requirement already satisfied: tqdm>=4.36.1 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from -r ./requirements.txt (line 1)) (4.64.1)
# Collecting ipywidgets
#   Downloading ipywidgets-8.0.2-py3-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.4/134.4 kB 19.7 MB/s eta 0:00:00
# Collecting widgetsnbextension~=4.0
#   Downloading widgetsnbextension-4.0.3-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 38.4 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>=4.3.1 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipywidgets->-r ./requirements.txt (line 2)) (5.3.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipywidgets->-r ./requirements.txt (line 2)) (6.15.2)
# Collecting jupyterlab-widgets~=3.0
#   Downloading jupyterlab_widgets-3.0.3-py3-none-any.whl (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.1/384.1 kB 28.5 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=6.1.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipywidgets->-r ./requirements.txt (line 2)) (8.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 2)) (0.1.6)
# Requirement already satisfied: pyzmq>=17 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 2)) (23.2.1)
# Requirement already satisfied: packaging in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 2)) (21.3)
# Requirement already satisfied: nest-asyncio in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 2)) (1.5.5)
# Requirement already satisfied: jupyter-client>=6.1.12 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 2)) (7.3.5)
# Requirement already satisfied: tornado>=6.1 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 2)) (6.2)
# Requirement already satisfied: psutil in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 2)) (5.9.2)
# Requirement already satisfied: debugpy>=1.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 2)) (1.6.3)
# Requirement already satisfied: stack-data in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 2)) (0.5.0)
# Requirement already satisfied: backcall in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 2)) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 2)) (0.17.2)
# Requirement already satisfied: pygments>=2.4.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 2)) (2.13.0)
# Requirement already satisfied: pickleshare in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 2)) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 2)) (3.0.31)
# Requirement already satisfied: decorator in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 2)) (5.1.1)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.9.2 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 2)) (4.11.1)
# Requirement already satisfied: entrypoints in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 2)) (0.4)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 2)) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from packaging->ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: asttokens in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 2)) (2.0.8)
# Requirement already satisfied: executing in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: pure-eval in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 2)) (0.2.2)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 2)) (1.16.0)
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
# Successfully installed ipywidgets-8.0.2 jupyterlab-widgets-3.0.3 widgetsnbextension-4.0.3
#
# [notice] A new release of pip available: 22.2.1 -> 22.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4f17627b-1a01-413e-b5c6-316bf312de2c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
